# %%
from nba_api.stats.static import teams

# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print("Number of teams fetched: {}".format(len(nba_teams)))
nba_teams
# Out:
# Number of teams fetched: 30
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
from nba_api.stats.static import players

# get_players returns a list of dictionaries, each representing a player.
nba_players = players.get_players()
print("Number of players fetched: {}".format(len(nba_players)))
nba_players
# Out:
# Number of players fetched: 4900
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False},
#  {'id': 949,
#   'full_name': 'Shareef Abdur-Rahim',
#   'first_name': 'Shareef',
#   'last_name': 'Abdur-Rahim',
#   'is_active': False},
#  {'id': 76005,
#   'full_name': 'Tom Abernethy',
#   'first_name': 'Tom',
#   'last_name': 'Abernethy',
#   'is_active': False},
# ...

# %%
names = [
    player for player in nba_players if player["is_active"] == 'Curry'
]

names
# Out:
# [{'id': 209,
#   'full_name': 'Dell Curry',
#   'first_name': 'Dell',
#   'last_name': 'Curry',
#   'is_active': False},
#  {'id': 2201,
#   'full_name': 'Eddy Curry',
#   'first_name': 'Eddy',
#   'last_name': 'Curry',
#   'is_active': False},
#  {'id': 201191,
#   'full_name': 'JamesOn Curry',
#   'first_name': 'JamesOn',
#   'last_name': 'Curry',
#   'is_active': False},
#  {'id': 688,
#   'full_name': 'Michael Curry',
#   'first_name': 'Michael',
#   'last_name': 'Curry',
#   'is_active': False},
#  {'id': 203552,
#   'full_name': 'Seth Curry',
#   'first_name': 'Seth',
#   'last_name': 'Curry',
#   'is_active': True},
#  {'id': 201939,
#   'full_name': 'Stephen Curry',
#   'first_name': 'Stephen',
#   'last_name': 'Curry',
#   'is_active': True}]

# %%
from nba_api.stats.endpoints import commonteamroster

celtics = commonteamroster.CommonTeamRoster(team_id='1610612738', season=2022).get_data_frames()[0]
celtics
# Out:
#         TeamID SEASON LeagueID               PLAYER NICKNAME  \
# 0   1610612738   2022       00         Jayson Tatum   Jayson
# 1   1610612738   2022       00         Jaylen Brown   Jaylen
# 2   1610612738   2022       00     Danilo Gallinari   Danilo
# 3   1610612738   2022       00        Derrick White  Derrick
# 4   1610612738   2022       00     Payton Pritchard   Payton
# 5   1610612738   2022       00       Grant Williams    Grant
# 6   1610612738   2022       00      Malcolm Brogdon  Malcolm
# 7   1610612738   2022       00           JD Davison       JD
# 8   1610612738   2022       00    Mfiondu Kabengele  Mfiondu
# 9   1610612738   2022       00           Sam Hauser      Sam
# 10  1610612738   2022       00         Marcus Smart   Marcus
# 11  1610612738   2022       00          Luke Kornet     Luke
# 12  1610612738   2022       00           Al Horford       Al
# 13  1610612738   2022       00  Robert Williams III   Robert
# ...

# %%
celtics['resultSets'][0]['rowSet'][0]
# Out:
# [1610612738,
#  '2022',
#  '00',
#  'Jayson Tatum',
#  'Jayson',
#  'jayson-tatum',
#  '0',
#  'F-G',
#  '6-8',
#  '210',
#  'MAR 03, 1998',
#  25.0,
#  '5',
#  'Duke',
#  1628369,
#  '#3 Pick in 2017 Draft']

# %%
rost = commonteamroster.CommonTeamRoster(team_id='1610612738', season=2022).get_dict()
rost
# Out:
# {'resource': 'commonteamroster',
#  'parameters': {'TeamID': 1610612738, 'LeagueID': None, 'Season': '2022'},
#  'resultSets': [{'name': 'CommonTeamRoster',
#    'headers': ['TeamID',
#     'SEASON',
#     'LeagueID',
#     'PLAYER',
#     'NICKNAME',
#     'PLAYER_SLUG',
#     'NUM',
#     'POSITION',
#     'HEIGHT',
#     'WEIGHT',
#     'BIRTH_DATE',
#     'AGE',
#     'EXP',
#     'SCHOOL',
#     'PLAYER_ID',
#     'HOW_ACQUIRED'],
#    'rowSet': [[1610612738,
#      '2022',
#      '00',
#      'Jayson Tatum',
#      'Jayson',
#      'jayson-tatum',
#      '0',
#      'F-G',
#      '6-8',
#      '210',
#      'MAR 03, 1998',
#      25.0,
#      '5',
#      'Duke',
#      1628369,
#      '#3 Pick in 2017 Draft'],
#     [1610612738,
#      '2022',
#      '00',
#      'Jaylen Brown',
#      'Jaylen',
#      'jaylen-brown',
#      '7',
#      'G-F',
#      '6-6',
#      '223',
#      'OCT 24, 1996',
#      26.0,
#      '6',
#      'California',
#      1627759,
# ...

# %%
rost['resultSets'][0]['rowSet'][0]
# Out:
# [1610612738,
#  '2022',
#  '00',
#  'Jayson Tatum',
#  'Jayson',
#  'jayson-tatum',
#  '0',
#  'F-G',
#  '6-8',
#  '210',
#  'MAR 03, 1998',
#  25.0,
#  '5',
#  'Duke',
#  1628369,
#  '#3 Pick in 2017 Draft']

# %%
for k, v in commonteamroster.CommonTeamRoster(team_id='1610612738', season=2022).get_dict().items():
    print(k)
# Out:
# resource
# parameters
# resultSets

# %%
from nba_api.stats.endpoints import playergamelog

tatum = playergamelog.PlayerGameLog(player_id='201939', season='2023', date_from_nullable="01/01/2024").get_dict()
tatum
# Out:
# {'resource': 'playergamelog',
#  'parameters': {'PlayerID': 201939,
#   'LeagueID': None,
#   'Season': '2023',
#   'SeasonType': 'Regular Season',
#   'DateFrom': '01/01/2024',
#   'DateTo': None},
#  'resultSets': [{'name': 'PlayerGameLog',
#    'headers': ['SEASON_ID',
#     'Player_ID',
#     'Game_ID',
#     'GAME_DATE',
#     'MATCHUP',
#     'WL',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS',
#     'PLUS_MINUS',
#     'VIDEO_AVAILABLE'],
#    'rowSet': [['22023',
#      201939,
#      '0022300478',
#      'JAN 04, 2024',
#      'GSW vs. DEN',
#      None,
#      26,
#      9,
#      16,
#      0.563,
#      4,
#      8,
#      0.5,
#      1,
#      1,
#      1.0,
#      0,
#      4,
#      4,
#      5,
#      1,
#      1,
#      1,
#      1,
#      23,
#      -3,
# ...

# %%
tatum['resultSets'][0]['rowSet'][0]
# Out:
# ['22023',
#  201939,
#  '0022300478',
#  'JAN 04, 2024',
#  'GSW vs. DEN',
#  None,
#  26,
#  9,
#  16,
#  0.563,
#  4,
#  8,
#  0.5,
#  1,
#  1,
#  1.0,
#  0,
#  4,
#  4,
#  5,
#  1,
#  1,
#  1,
#  1,
#  23,
#  -3,
#  0]

# %%
import pandas as pd

df = pd.read_csv('db/draft_salary.csv')
df
# Out:
#      Rank                   PLAYER    POS TEAM  TOTAL
# 0       1              Joel Embiid      C  PHI  17.38
# 1       2  Shai Gilgeous-Alexander  PG+SG  OKC  16.82
# 2       3             Nikola Jokic      C  DEN  13.60
# 3       4              Luka Doncic     PG  DAL  12.30
# 4       5            Anthony Davis   PF+C  LAL  11.60
# ..    ...                      ...    ...  ...    ...
# 195   196           Toumani Camara     PF  POR  -2.27
# 196   197              Maxi Kleber   PF+C  DAL  -2.34
# 197   198         Lonnie Walker IV  SG+SF  BKN  -2.37
# 198   199           Isaiah Jackson   PF+C  IND  -2.40
# 199   200          Christian Braun     SG  DEN  -2.41
#
# [200 rows x 5 columns]

# %%
for key, values in df.to_dict(orient='index').items():
    print(values)
# Out:
# {'Rank': 1, 'PLAYER': 'Joel Embiid', 'POS': 'C', 'TEAM': 'PHI', 'TOTAL': 17.38}
# {'Rank': 2, 'PLAYER': 'Shai Gilgeous-Alexander', 'POS': 'PG+SG', 'TEAM': 'OKC', 'TOTAL': 16.82}
# {'Rank': 3, 'PLAYER': 'Nikola Jokic', 'POS': 'C', 'TEAM': 'DEN', 'TOTAL': 13.6}
# {'Rank': 4, 'PLAYER': 'Luka Doncic', 'POS': 'PG', 'TEAM': 'DAL', 'TOTAL': 12.3}
# {'Rank': 5, 'PLAYER': 'Anthony Davis', 'POS': 'PF+C', 'TEAM': 'LAL', 'TOTAL': 11.6}
# {'Rank': 6, 'PLAYER': 'Kevin Durant', 'POS': 'SF+PF', 'TEAM': 'PHO', 'TOTAL': 11.45}
# {'Rank': 7, 'PLAYER': 'Tyrese Haliburton', 'POS': 'PG+SG', 'TEAM': 'IND', 'TOTAL': 9.52}
# {'Rank': 8, 'PLAYER': 'James Harden', 'POS': 'PG+SG', 'TEAM': 'LAC', 'TOTAL': 9.44}
# {'Rank': 9, 'PLAYER': 'Trae Young', 'POS': 'PG', 'TEAM': 'ATL', 'TOTAL': 9.34}
# {'Rank': 10, 'PLAYER': 'Victor Wembanyama', 'POS': 'PF+C', 'TEAM': 'SA', 'TOTAL': 9.22}
# {'Rank': 11, 'PLAYER': 'Damian Lillard', 'POS': 'PG', 'TEAM': 'MIL', 'TOTAL': 9.13}
# ...

# %%
from datetime import datetime

# Get the current date and time
now = datetime.now()

formatted_date = now.strftime("%m/%d/%Y")

print("Current Date in dd/mm/yyyy format:", formatted_date)
# Out:
# Current Date in dd/mm/yyyy format: 01/04/2024

# %%
from nba_api.stats.endpoints import playergamelog

curry = playergamelog.PlayerGameLog(player_id='201939', season='2023', date_from_nullable=formatted_date).get_data_frames()[0]
curry
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22023     201939  0022300478  JAN 04, 2024  GSW vs. DEN  L   35   11
#
#    FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   23   0.478  ...     4    4    6    1    1    2   1   30          -1
#
#    VIDEO_AVAILABLE
# 0                1
#
# [1 rows x 27 columns]

# %%
playergamelog.PlayerGameLog(player_id='201939', season='2023', date_from_nullable=formatted_date).get_dict()['resultSets'][0]['rowSet']
# Out:
# [['22023',
#   201939,
#   '0022300478',
#   'JAN 04, 2024',
#   'GSW vs. DEN',
#   'L',
#   35,
#   11,
#   23,
#   0.478,
#   5,
#   12,
#   0.417,
#   3,
#   3,
#   1.0,
#   0,
#   4,
#   4,
#   6,
#   1,
#   1,
#   2,
#   1,
#   30,
#   -1,
#   1]]

# %% [markdown]
# SELECT players.full_name, player_gamelog.game_date, deadlines.gameweek, deadlines.day, pts + reb*1.2 + ast*1.5 + blk*2 + stl*2 + tov*-1 as fantasy_points FROM player_gamelog, players, deadlines WHERE players.id = player_gamelog.player_id AND player_gamelog.game_date = deadlines.deadline ORDER BY deadlines.gameweek, deadlines.day, players.full_name;
